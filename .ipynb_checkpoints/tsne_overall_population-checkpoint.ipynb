# %%
# %matplotlib inline
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE 
import nbimporter
from Analysis import kmeans
import time
# Out:
# Importing Jupyter notebook from /Users/mirandago/Desktop/284-team-project/Analysis/kmeans.ipynb

# %%
# Only using the top 15 PCs
pc = np.load('./PCA_top100.npy')
pc = pc[:,0:70]
print(np.shape(pc))
# Out:
# (2504, 70)

# %%
#Perform tSNE
start = time.perf_counter()
tSNE = TSNE(n_components=2).fit_transform(pc)
end = time.perf_counter()
print("TIME:")
print(end-start)
print(np.shape(tSNE))
# Out:
# TIME:
# 20.502457063001202
# (2504, 2)

# %%
#Plot tSNE data

#Load population labels
sample_to_pop = {}
with open("df_pop.csv", "r") as f:
    for line in f:  
        sample, pop = line.strip().split(",")
        sample_to_pop[sample] = pop

pop_to_color = {
    # EAS - yellow & orange
    "CHB": "yellow", "JPT": "khaki", "CHS": "gold", "CDX": "orange", "KHV": "darkorange", 
    # EUR - blue
    "CEU": "blue", "TSI": "dodgerblue", "FIN": "deepskyblue", "GBR": "darkblue", "IBS": "royalblue",
    # AFR - green
    "YRI": "green", "LWK": "forestgreen", "GWD": "limegreen", "MSL": "lime", "ESN": "greenyellow", 
    "ASW": "springgreen", "ACB": "seagreen", 
    # AMR - purple
    "MXL": "purple", "PUR": "darkviolet", "CLM": "magenta", "PEL": "deeppink", 
    # SAS - red
    "GIH": "red", "PJL": "crimson", "BEB": "firebrick", "STU": "lightcoral", "ITU": "indianred", 
    # None
    "None": "lightgrey"  
}

colors = []
sample_names = []
for sample in sample_to_pop.values():
    if len(sample) == 3:
        color = pop_to_color[sample]
        colors.append(color)    
    
tsne1 = tSNE[0:, 0:1].transpose()[0]
tsne2 = tSNE[0:, 1:2].transpose()[0]

# Make the plot
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(tsne1, tsne2, color=colors, s=5)
ax.set_xlabel("TSNE 1", size=15)
ax.set_ylabel("TSNE 2", size=15)
ax.set_xticklabels(ax.get_xticks(), size=12)
ax.set_yticklabels(ax.get_yticks(), size=12)
ax.spines["top"].set_visible(False);
ax.spines["right"].set_visible(False);
ax.get_xaxis().tick_bottom();
ax.get_yaxis().tick_left();

# %% [markdown]
# ## KMeans Clustering into 5 Clusters

# %%
kmeans.kmeans(tSNE)
# Out:
# Group 1. Legend Index:
# 3
# Accuracy:
# 0.9816849816849816
# Group 2. Legend Index:
# 1
# Accuracy:
# 0.9864457831325302
# Group 3. Legend Index:
# 2
# Accuracy:
# 0.998019801980198
# Group 4. Legend Index:
# 4
# Accuracy:
# 1.0
# Group 5. Legend Index:
# 0
# Accuracy:
# 0.8778359511343804
# Total Accuracy:
# 0.968797303586418
# 0.968797303586418

# %%
# Determining Perplexity
# perplexity = []
# accuracy = []
# for i in range(0, 51, 5):
#     print("Perplexity:")
#     print(i)
    
#     tSNE = TSNE(n_components=2, perplexity=i).fit_transform(pc)
#     accuracy += [kmeans.kmeans(tSNE)]

# print(accuracy)
# Out:
# Perplexity:
# 0
# Group 1. Legend Index:
# 1
# Accuracy:
# 0.273972602739726
# Group 2. Legend Index:
# 1
# Accuracy:
# 0.2515592515592516
# Group 3. Legend Index:
# 1
# Accuracy:
# 0.25346534653465347
# Group 4. Legend Index:
# 1
# Accuracy:
# 0.28489483747609945
# Group 5. Legend Index:
# 1
# Accuracy:
# 0.25413223140495866
# Total Accuracy:
# 0.2636048539429378
# Perplexity:
# 5
# Group 1. Legend Index:
# 2
# Accuracy:
# 0.998019801980198
# Group 2. Legend Index:
# 3
# Accuracy:
# 0.6962750716332379
# Group 3. Legend Index:
# 0
# Accuracy:
# 0.8408710217755444
# Group 4. Legend Index:
# 1
# Accuracy:
# 0.9840425531914894
# Group 5. Legend Index:
# 4
# Accuracy:
# 1.0
# Total Accuracy:
# 0.9038416897160939
# Perplexity:
# 10
# Group 1. Legend Index:
# 0
# Accuracy:
# 0.8884955752212389
# Group 2. Legend Index:
# 1
# Accuracy:
# 0.9923547400611621
# Group 3. Legend Index:
# 4
# Accuracy:
# 1.0
# Group 4. Legend Index:
# 3
# Accuracy:
# 0.9587628865979382
# Group 5. Legend Index:
# 2
# Accuracy:
# 0.998019801980198
# Total Accuracy:
# 0.9675266007721074
# Perplexity:
# 15
# Group 1. Legend Index:
# 3
# Accuracy:
# 0.8860759493670886
# Group 2. Legend Index:
# 4
# Accuracy:
# 1.0
# Group 3. Legend Index:
# 2
# Accuracy:
# 0.998019801980198
# Group 4. Legend Index:
# 0
# Accuracy:
# 0.8871252204585538
# Group 5. Legend Index:
# 1
# Accuracy:
# 0.9952153110047847
# Total Accuracy:
# 0.9532872565621251
# Perplexity:
# 20
# Group 1. Legend Index:
# 2
# Accuracy:
# 0.998019801980198
# Group 2. Legend Index:
# 0
# Accuracy:
# 0.8763066202090593
# Group 3. Legend Index:
# 1
# Accuracy:
# 0.9820089955022488
# Group 4. Legend Index:
# 4
# Accuracy:
# 1.0
# Group 5. Legend Index:
# 3
# Accuracy:
# 0.9814126394052045
# Total Accuracy:
# 0.9675496114193421
# Perplexity:
# 25
# Group 1. Legend Index:
# 1
# Accuracy:
# 0.9849624060150376
# Group 2. Legend Index:
# 3
# Accuracy:
# 0.9817518248175182
# Group 3. Legend Index:
# 0
# Accuracy:
# 0.8809106830122592
# Group 4. Legend Index:
# 2
# Accuracy:
# 0.998019801980198
# Group 5. Legend Index:
# 4
# Accuracy:
# 1.0
# Total Accuracy:
# 0.9691289431650028
# Perplexity:
# 30
# Group 1. Legend Index:
# 1
# Accuracy:
# 0.9849624060150376
# Group 2. Legend Index:
# 4
# Accuracy:
# 1.0
# Group 3. Legend Index:
# 0
# Accuracy:
# 0.8902654867256637
# Group 4. Legend Index:
# 2
# Accuracy:
# 0.998019801980198
# Group 5. Legend Index:
# 3
# Accuracy:
# 0.9785714285714285
# Total Accuracy:
# 0.9703638246584655
# Perplexity:
# 35
# Group 1. Legend Index:
# 4
# Accuracy:
# 1.0
# Group 2. Legend Index:
# 2
# Accuracy:
# 0.998019801980198
# Group 3. Legend Index:
# 0
# Accuracy:
# 0.870242214532872
# Group 4. Legend Index:
# 1
# Accuracy:
# 0.9834834834834835
# Group 5. Legend Index:
# 3
# Accuracy:
# 0.981203007518797
# Total Accuracy:
# 0.9665897015030701
# Perplexity:
# 40
# Group 1. Legend Index:
# 4
# Accuracy:
# 1.0
# Group 2. Legend Index:
# 0
# Accuracy:
# 0.8717504332755632
# Group 3. Legend Index:
# 1
# Accuracy:
# 0.990909090909091
# Group 4. Legend Index:
# 2
# Accuracy:
# 0.998019801980198
# Group 5. Legend Index:
# 3
# Accuracy:
# 0.9816849816849816
# Total Accuracy:
# 0.9684728615699667
# Perplexity:
# 45
# Group 1. Legend Index:
# 2
# Accuracy:
# 0.998019801980198
# Group 2. Legend Index:
# 0
# Accuracy:
# 0.8763066202090593
# Group 3. Legend Index:
# 4
# Accuracy:
# 1.0
# Group 4. Legend Index:
# 1
# Accuracy:
# 0.9909228441754917
# Group 5. Legend Index:
# 3
# Accuracy:
# 0.9818181818181818
# Total Accuracy:
# 0.9694134896365861
# Perplexity:
# 50
# Group 1. Legend Index:
# 1
# Accuracy:
# 0.9938744257274119
# Group 2. Legend Index:
# 3
# Accuracy:
# 0.9652777777777778
# Group 3. Legend Index:
# 2
# Accuracy:
# 0.998019801980198
# Group 4. Legend Index:
# 4
# Accuracy:
# 1.0
# Group 5. Legend Index:
# 0
# Accuracy:
# 0.8840070298769771
# Total Accuracy:
# 0.968235807072473
# [None, None, None, None, None, None, None, None, None, None, None]

# %%
# plt.plot([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50], [0.264, 0.904, 0.968, 0.953, 0.968, 0.970, 0.967, 0.968, 0.969, 0.970, 0.968])
# plt.xlabel('Value for Perplexity')
# plt.ylabel('KMeans Accuracy')
# Out:
# Text(0,0.5,'KMeans Accuracy')
